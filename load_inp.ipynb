# %%
from tespa import TesPa

tespa = TesPa()  # Create a global TesPa instance

tespa.load_dust_config("sim.ini", verbose=True)  # Load configuration from sim.ini
# Out:
# Initialized box with size  100 100 100 meters
# Dust Params: N particles: 500
# density=2000.0 kg/m3
# average rdust=1.00e-06 m
# average mass=8.38e-15 kg
# Initial geometry: sphere
# average initial velocity: 0.0 m/s
#
# Plasma Params:
# ne0=1.00e+15 m^-3
# ni0=1.00e+15 m^-3
# Te=23209.05 K
# Ti=348.14 K
# mass_ratio=1836.00
# photoemission_current_density=0.00e+00 A/m^2
# nn0=5.00e+21 m^-3
# nphe0=0.00e+00 m^-3
# Tn=300.00 K
# neutral_species=Ar
# neutral_mass=6.63e-26 kg
# neutral_delta=1.44
