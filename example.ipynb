# %%
import tespa
import numpy as np

# Create a TesPa object
sim = tespa.TesPa()
# Tell the object where to load the EMSES files
sim.load_emses("../data/sub_vx_fp_magz_small", 0.0025)

# If B is constant it must we set manually as EMSES data does not write it
sim.set_B(90e-6,dir="z")

# Print some info about the simulation
print(sim)

m = 9.10938356e-31 # Particle mass
q = -1.60217662e-19 # Particle charge
r0 = np.array([0.3, 0.2, 0.3]) # Initial position in m
v0 = np.array([1.0e6, 0.0, 0.0]) # Initial speed in m/s
dt0 = 1e-9 # Inital time step for the adaptive time step method
# Out:
# Loading data from  ../data/sub_vx_fp_magz_small
# Offsetting E fields by  0.00125
# Offsetting phisp fields by  0.00125
# Data loaded from ../data/sub_vx_fp_magz_small
# Dimensions in meters (x,y,z): (0.8, 0.8, 0.8) with dx = 0.0025

# %%
m = 9.10938356e-31 # Particle mass
q = -1.60217662e-19 # Particle charge
r0 = np.array([0.3, 0.2, 0.3]) # Initial position in m
v0 = np.array([1.0e6, 0.0, 0.0]) # Initial speed in m/s
dt0 = 1e-9 # Inital time step for the adaptive time step method
sim.run_simple(r0,v0,m,q,dt0=dt0,Nt = 10000)
print(r0)
# Out:
# Timestep index of data storage:  2
# Compiling...
# Running simulation with  1  initial conditions
# Particle still in domain after final timestep at [0.35844945 0.24045526 0.29999969]
#
# Simulation finished
# [0.3 0.2 0.3]

# %% [markdown]
# # Some plotting examples

# %%
def plot_phisp(sim,ax,slice):
    # Plot the potential
    phi = sim.data.phisp
    ax.imshow(phi[slice],origin="lower",aspect="auto")
    #ax.set_title("Potential")

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,1)
print(sim.r.shape)
print(sim.r[:,0])
ax.plot(sim.r[0,:],sim.r[1,:])
print(sim.r[:,0])
plot_phisp(sim,ax,np.s_[:,:, 50])
#plt.xlim(0,sim.data.x[-1])
#plt.ylim(0,sim.data.y[-1])
# Out:
# (3, 5000)
# [0.3 0.2 0.3]
# [0.3 0.2 0.3]

# %%
idx = 1000
plt.plot(sim.t[:idx],sim.r[0,:idx])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a grid of points (x, y)
x = np.linspace(-2, 2, 10)
y = np.linspace(-2, 2, 10)
X, Y = np.meshgrid(x, y)

# Define vector components (U, V) for each point
U = Y   # Vector component in the x-direction
V = X    # Vector component in the y-direction

# Create the quiver plot
plt.quiver(X, Y, U, V, color = "w")

# Optionally, set the aspect ratio to be equal
plt.axis('equal')

# Show the plot
plt.show()
